# %%
# !pip install onnx onnxruntime onnx2torch

# %%
import onnxruntime as ort
import onnx

# %%
session = ort.InferenceSession("maia2_models/maia1100.onnx")

input_name = session.get_inputs()[0].name
input_name
# Out:
# '/input/planes'

# %%
import onnx 
model = onnx.load("maia2_models/maia1100.onnx")
onnx.checker.check_model(model)
print(model.graph)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
from onnx2torch import convert
model = convert("models/maia-1100.onnx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 from onnx2torch import convert
# ----> 2 model = convert("models/maia-1100.onnx")
#
# File /opt/conda/lib/python3.12/site-packages/onnx2torch/converter.py:72, in convert(onnx_model_or_path, save_input_names, attach_onnx_mapping)
#      39 def convert(  # pylint: disable=too-many-locals, too-many-branches, too-many-statements
#      40     onnx_model_or_path: Union[str, Path, ModelProto],
#      41     save_input_names: bool = False,
#      42     attach_onnx_mapping: bool = False,
#      43 ) -> fx.GraphModule:
#      44     """Convert model from onnx to PyTorch.
#      45
#      46     This function build torch.fx GraphModule from onnx ModelProto using operations from the converter registry.
#    (...)
#      69
#      70     """
# ---> 72     onnx_model = safe_shape_inference(onnx_model_or_path)
# ...
