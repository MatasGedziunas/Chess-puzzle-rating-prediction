# %%
# !pip install chess==1.10.0 einops==0.8.0 gdown==5.2.0 numpy==2.1.3 pandas==2.2.3 pyzstd==0.15.9 Requests==2.32.3 tqdm==4.65.0 maia2
# Out:
# Collecting chess==1.10.0
#   Using cached chess-1.10.0-py3-none-any.whl.metadata (19 kB)
# Collecting einops==0.8.0
#   Using cached einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting gdown==5.2.0
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy==2.1.3 in /opt/conda/lib/python3.12/site-packages (2.1.3)
# Requirement already satisfied: pandas==2.2.3 in /opt/conda/lib/python3.12/site-packages (2.2.3)
# Collecting pyzstd==0.15.9
#   Using cached pyzstd-0.15.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: Requests==2.32.3 in /opt/conda/lib/python3.12/site-packages (2.32.3)
# Collecting tqdm==4.65.0
#   Using cached tqdm-4.65.0-py3-none-any.whl.metadata (56 kB)
# Requirement already satisfied: maia2 in /opt/conda/lib/python3.12/site-packages (0.9)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.12/site-packages (from gdown==5.2.0) (4.13.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from gdown==5.2.0) (3.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3) (2025.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from Requests==2.32.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from Requests==2.32.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from Requests==2.32.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from Requests==2.32.3) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4->gdown==5.2.0) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4->gdown==5.2.0) (4.15.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.12/site-packages (from requests[socks]->gdown==5.2.0) (1.7.1)
# Using cached chess-1.10.0-py3-none-any.whl (154 kB)
# Using cached einops-0.8.0-py3-none-any.whl (43 kB)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Using cached pyzstd-0.15.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (411 kB)
# Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Installing collected packages: tqdm, pyzstd, einops, chess, gdown
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: pyzstd
#     Found existing installation: pyzstd 0.19.1
#     Uninstalling pyzstd-0.19.1:
#       Successfully uninstalled pyzstd-0.19.1
#   Attempting uninstall: chess
#     Found existing installation: chess 1.11.2
#     Uninstalling chess-1.11.2:
#       Successfully uninstalled chess-1.11.2
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.2.1
#     Uninstalling gdown-5.2.1:
#       Successfully uninstalled gdown-5.2.1
# Successfully installed chess-1.10.0 einops-0.8.0 gdown-5.2.0 pyzstd-0.15.9 tqdm-4.65.0

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.12/site-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.12/site-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.12/site-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch) (2025.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/conda/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/conda/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/conda/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/conda/lib/python3.12/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/conda/lib/python3.12/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/conda/lib/python3.12/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/conda/lib/python3.12/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/conda/lib/python3.12/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /opt/conda/lib/python3.12/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/conda/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/conda/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/conda/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /opt/conda/lib/python3.12/site-packages (from torch) (3.2.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.12/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)

# %%
import torch
from maia2 import model, inference
import pandas as pd
import numpy as np
from tqdm import tqdm
import chess
import os

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
maia2_model = model.from_pretrained(type="rapid", device=device)
maia2_model.eval()

dummy_input = torch.randn(2, 18, 8, 8, device=device)
dummy_elo = torch.zeros(2, device=device).long()

with torch.no_grad():
    out = maia2_model(dummy_input, elos_self=dummy_elo, elos_oppo=dummy_elo)

print(f"Output is a tuple of length: {len(out)}")
for i, tensor in enumerate(out):
    print(f"Index {i} Tensor Shape: {tensor.shape}")
# Out:
# Model for rapid games already downloaded.
# Model for rapid games loaded to cpu.
# Output is a tuple of length: 3
# Index 0 Tensor Shape: torch.Size([2, 1880])
# Index 1 Tensor Shape: torch.Size([2, 2021])
# Index 2 Tensor Shape: torch.Size([2])

# %%
for name, child in maia2_model.named_children():
    print(name)
# Out:
# chess_cnn
# to_patch_embedding
# transformer
# fc_1
# fc_2
# fc_3
# fc_3_1
# elo_embedding
# dropout
# last_ln

# %%
class FeatureExtractor:
    def __init__(self, model):
        self.model = model
        self.latent_vector = None
        self.hook = self.model.last_ln.register_forward_hook(self.save_output)

    def save_output(self, module, input, output):
        self.latent_vector = output

    def __call__(self, boards, elo_self, elo_oppo):
        self.model(boards, elos_self=elo_self, elos_oppo=elo_oppo)
        return self.latent_vector

def process_dataset(df, elo_indices=[0], batch_size=64):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    maia2_model = model.from_pretrained(type="rapid", device=device)
    maia2_model.to(device)
    maia2_model.eval()
    extractor = FeatureExtractor(maia2_model)
    fens = df['FEN'].tolist()
    num_puzzles = len(fens)
    num_elos = len(elo_indices)
    
    # (Puzzles, Elos, 1024 features)
    all_results = np.zeros((num_puzzles, num_elos, 1024), dtype=np.float32)
    
    for i in tqdm(range(0, num_puzzles, batch_size)):
        batch_end = min(i + batch_size, num_puzzles)
        batch_fens = fens[i:batch_end]
        
        batch_tensors = [inference.board_to_tensor(chess.Board(f)) for f in batch_fens]
        boards = torch.stack(batch_tensors).to(device)
        
        for elo_idx_in_list, skill_val in enumerate(elo_indices):
            elos = torch.full((len(batch_fens),), skill_val, device=device).long()
            
            with torch.no_grad():
                latent = extractor(boards, elos, elos)
                all_results[i:batch_end, elo_idx_in_list, :] = latent.cpu().numpy()
                
    return all_results

# %%
elo_dict = inference.create_elo_dict()

ratings_to_test = [500,1100,1250, 1300, 1500, 1700, 1900, 2100, 2300, 2500, 3000]
for r in ratings_to_test:
    idx = inference.map_to_category(r, elo_dict)
    print(f"Rating {r} -> Index {idx}")
# Out:
# Rating 500 -> Index 0
# Rating 1100 -> Index 1
# Rating 1250 -> Index 2
# Rating 1300 -> Index 3
# Rating 1500 -> Index 5
# Rating 1700 -> Index 7
# Rating 1900 -> Index 9
# Rating 2100 -> Index 10
# Rating 2300 -> Index 10
# Rating 2500 -> Index 10
# Rating 3000 -> Index 10

# %%
df = pd.read_csv('../data/puzzle50000.csv')

# %%
feat = process_dataset(df, [i for i in range(0, 11)])
# Out:
# Model for rapid games already downloaded.
# Model for rapid games loaded to cuda.
# 100%|██████████| 782/782 [00:28<00:00, 26.99it/s]

# %%
output_dir = "../features"

features_file = os.path.join(output_dir, "maia2_latent_features.npy")
np.save(features_file, feat)

ids_file = os.path.join(output_dir, "maia2_puzzle_ids.npy")
np.save(ids_file, df['PuzzleId'].values)

print(f"Success! Features saved to: {features_file}")
print(f"IDs saved to: {ids_file}")
# Out:
# Success! Features saved to: ../features/maia2_latent_features.npy
# IDs saved to: ../features/maia2_puzzle_ids.npy

# %%
output_dir = "../latentFeatures"
os.makedirs(output_dir, exist_ok=True)

feat_subset = feat[:1000, :, :]
ids_subset = df['PuzzleId'].values[:1000]

np.save(os.path.join(output_dir, "maia2_latent_subset_2k.npy"), feat_subset)
np.save(os.path.join(output_dir, "maia2_subset_2k_ids.npy"), ids_subset)

# %%
def process_puzzle_sequences(df, elo_indices=[0], max_steps=10):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    maia2_model = model.from_pretrained(type="rapid", device=device)
    maia2_model.to(device)
    maia2_model.eval()
    extractor = FeatureExtractor(maia2_model)
    
    num_puzzles = len(df)
    num_elos = len(elo_indices)
    sequence_results = np.zeros((num_puzzles, max_steps, num_elos, 1024), dtype=np.float32)
    
    for p_idx, row in tqdm(df.iterrows(), total=num_puzzles):
        board = chess.Board(row['FEN'])
        moves = row['Moves'].split()
        
        puzzle_fens = [board.fen()]
        for move_str in moves[:max_steps-1]:
            try:
                move = chess.Move.from_uci(move_str)
                board.push(move)
                puzzle_fens.append(board.fen())
            except:
                break
        
        num_steps = len(puzzle_fens)
        batch_tensors = [inference.board_to_tensor(chess.Board(f)) for f in puzzle_fens]
        boards = torch.stack(batch_tensors).to(device)
        
        for elo_idx_in_list, skill_val in enumerate(elo_indices):
            elos = torch.full((num_steps,), skill_val, device=device).long()
            with torch.no_grad():
                latent = extractor(boards, elos, elos)
                sequence_results[p_idx, :num_steps, elo_idx_in_list, :] = latent.cpu().numpy()
                
    return sequence_results

output_features = process_puzzle_sequences(df, elo_indices=[0, 5, 10], max_steps=10)

np.save("../features/maia2_sequence_embeddings2.npy", output_features)
print("Saved sequence embeddings to ./features/maia2_sequence_embeddings.npy")
# Out:
# Model for rapid games already downloaded.
# Model for rapid games loaded to cuda.
#   1%|          | 549/50000 [00:04<06:19, 130.31it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 37
#      33                 sequence_results[p_idx, :num_steps, elo_idx_in_list, :] = latent.cpu().numpy()
#      35     return sequence_results
# ---> 37 output_features = process_puzzle_sequences(df, elo_indices=[0, 5, 10], max_steps=10)
#      39 np.save("../features/maia2_sequence_embeddings.npy", output_features)
#      40 print("Saved sequence embeddings to ./features/maia2_sequence_embeddings.npy")
#
# Cell In[17], line 32, in process_puzzle_sequences(df, elo_indices, max_steps)
#      30         elos = torch.full((num_steps,), skill_val, device=device).long()
#      31         with torch.no_grad():
# ---> 32             latent = extractor(boards, elos, elos)
#      33             sequence_results[p_idx, :num_steps, elo_idx_in_list, :] = latent.cpu().numpy()
#      35 return sequence_results
#
# Cell In[7], line 11, in FeatureExtractor.__call__(self, boards, elo_self, elo_oppo)
#      10 def __call__(self, boards, elo_self, elo_oppo):
# ---> 11     self.model(boards, elos_self=elo_self, elos_oppo=elo_oppo)
#      12     return self.latent_vector
#
# File /opt/conda/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/conda/lib/python3.12/site-packages/maia2/main.py:410, in MAIA2Model.forward(self, boards, elos_self, elos_oppo)
#     408 elos_emb_oppo = self.elo_embedding(elos_oppo)
#     409 elos_emb = torch.cat((elos_emb_self, elos_emb_oppo), dim=1)
# --> 410 x = self.transformer(x, elos_emb).mean(dim=1)
#     412 x = self.last_ln(x)
#     414 logits_maia = self.fc_1(x)
#
# File /opt/conda/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/conda/lib/python3.12/site-packages/maia2/main.py:361, in Transformer.forward(self, x, elo_emb)
#     359 def forward(self, x, elo_emb):
#     360     for attn, ff in self.elo_layers:
# --> 361         x = attn(x, elo_emb) + x
#     362         x = ff(x) + x
#     364     return self.norm(x)
#
# File /opt/conda/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/conda/lib/python3.12/site-packages/maia2/main.py:339, in EloAwareAttention.forward(self, x, elo_emb)
#     335 q = q + elo_effect
#     337 dots = torch.matmul(q, k.transpose(-1, -2)) * self.scale
# --> 339 attn = self.attend(dots)
#     340 attn = self.dropout(attn)
#     342 out = torch.matmul(attn, v)
#
# File /opt/conda/lib/python3.12/site-packages/torch/nn/modules/module.py:1915, in Module.__getattr__(self, name)
#    1910         self._backward_pre_hooks = OrderedDict()
#    1912 # It is crucial that the return type is not annotated as `Any`, otherwise type checking
#    1913 # on `torch.nn.Module` and all its subclasses is largely disabled as a result. See:
#    1914 # https://github.com/pytorch/pytorch/pull/115074
# -> 1915 def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#    1916     if "_parameters" in self.__dict__:
#    1917         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:

# %%
import tensorflow as tf

def inspect_nodes(pb_path):
    with tf.io.gfile.GFile(pb_path, "rb") as f:
        graph_def = tf.compat.v1.GraphDef()
        graph_def.ParseFromString(f.read())
    
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(graph_def, name="")
    
    ops = graph.get_operations()
    
    # 1. Look for placeholders (standard input type)
    print("--- INPUTS (Placeholders) ---")
    placeholders = [op for op in ops if op.type == "Placeholder"]
    for op in placeholders:
        print(f"Name: {op.name}, Output: {op.name}:0")
    
    # 2. Look for the last few nodes in the graph (usually outputs)
    print("\n--- POTENTIAL OUTPUTS (Last 5 Nodes) ---")
    for op in ops[-5:]:
        print(f"Name: {op.name}, Type: {op.type}")

    # 3. Just show the first 10 nodes to see the naming convention
    print("\n--- STARTING NODES (First 10) ---")
    for op in ops[:10]:
        print(f"Name: {op.name}, Type: {op.type}")

inspect_nodes("maia-1100.pb")
# Out:
# --- INPUTS (Placeholders) ---
#
# --- POTENTIAL OUTPUTS (Last 5 Nodes) ---
#
# --- STARTING NODES (First 10) ---
